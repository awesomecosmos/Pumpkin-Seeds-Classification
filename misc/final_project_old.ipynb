# %% [markdown]
# # CS619 Data Mining Final Project
#
# Aayushi Verma (#U01865004)

# %% [markdown]
# ## Project Synopsis
#
# In this research project, I

# %%
# importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df0 = pd.read_csv('Pumpkin_Seeds.csv')
df0.describe()

# %%
# generating a correlation matrix to see how the variables are related to each other
X = df0.drop('Class', axis = 1)
y = df0['Class']
corr = X.corr()
corr.style.background_gradient('coolwarm')

# %% [markdown]
# ### Post-Classification Results Analysis

# %%
df = pd.read_csv('project.csv')
df.rename({'Unnamed: 0':'traintype'},axis=1,inplace=True)
df.groupby('traintype').count()

# %%
training_data_only = df[(df['traintype']!='train60-te') & (df['traintype']!='train80-te')].sort_values('CorrectPercent',ascending=False)

# %%
algorithms = np.unique(df["Algorithm"]).tolist()

train60_tr = df[df["traintype"]=="train60-tr"]#.sort_values('CorrectPercent',ascending=False)
train60_te = df[df["traintype"]=="train60-te"]#.sort_values('CorrectPercent',ascending=False)
train80_tr = df[df["traintype"]=="train80-tr"]#.sort_values('CorrectPercent',ascending=False)
train80_te = df[df["traintype"]=="train80-te"]#.sort_values('CorrectPercent',ascending=False)
cv10 = df[df["traintype"]=="cv10"]#.sort_values('CorrectPercent',ascending=False)
cv5 = df[df["traintype"]=="cv5"]#.sort_values('CorrectPercent',ascending=False)

# %%
# fig, ax = plt.subplots(2, 2, sharex=True, sharey=False, figsize=(10, 10), dpi=300)

# #row=0, col=0
# ax[0, 0].scatter(train60_tr["Algorithm"],train60_tr["CorrectPercent"],color="red",alpha=1,label="train60") 
# ax[0, 0].scatter(train80_tr["Algorithm"],train80_tr["CorrectPercent"],color="blue",alpha=1,label="train80")
# ax[0, 0].grid(True)
# ax[0, 0].set_ylim(80,100)
# ax[0, 0].set_xlabel("algorithm")
# ax[0, 0].set_ylabel("correctly-classified percentage (%)")
# ax[0, 0].set_title("Correctly-Classified Instances for Training Data")
# ax[0, 0].legend()
# ax[0, 0].tick_params(axis='x', labelrotation=45)

# #row=0, col=1
# ax[0, 1].scatter(train60_te["Algorithm"],train60_te["CorrectPercent"],color="red",alpha=1,label="train60") 
# ax[0, 1].scatter(train80_te["Algorithm"],train80_te["CorrectPercent"],color="blue",alpha=1,label="train80")
# ax[0, 1].grid(True)
# ax[0, 1].set_ylim(80,100)
# ax[0, 1].set_xlabel("algorithm")
# # ax[0, 1].set_ylabel("correctly-classified percentage (%)")
# ax[0, 1].set_title("Correctly-Classified Instances for Testing Data")
# ax[0, 1].legend()

# #row=1, col=0
# ax[1, 0].scatter(train60_tr["Algorithm"],train60_tr["MAE"],color="red",alpha=1,label="train60") #row=0, col=0
# ax[1, 0].scatter(train80_tr["Algorithm"],train80_tr["MAE"],color="blue",alpha=1,label="train80")
# ax[1, 0].grid(True)
# ax[1, 0].set_ylim(0,0.3)
# ax[1, 0].set_xlabel("algorithm")
# ax[1, 0].set_ylabel("MAE")
# ax[1, 0].set_title("MAE for Training Data")
# ax[1, 0].legend()
# ax[1, 0].tick_params(axis='x', labelrotation=45)
# # plt.xticks(rotation=45)

# #row=1, col=1
# ax[1, 1].scatter(train60_tr["Algorithm"],train60_tr["MAE"],color="red",alpha=1,label="train60") 
# ax[1, 1].scatter(train80_tr["Algorithm"],train80_tr["MAE"],color="blue",alpha=1,label="train80")
# ax[1, 1].grid(True)
# ax[1, 1].set_ylim(0,0.3)
# ax[1, 1].set_xlabel("algorithm")
# # ax[1, 1].set_ylabel("MAE")
# ax[1, 1].set_title("MAE for Testing Data")
# ax[1, 1].legend()
# ax[1, 1].tick_params(axis='x', labelrotation=45)

# plt.savefig("plots/project_train_percentage_training_and_testing.jpg",dpi=300)

# %%
# fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False, figsize=(7, 10), dpi=300)

# #row=0, col=0
# ax[0].scatter(cv5["Algorithm"],cv5["CorrectPercent"],color="red",alpha=1,label="cv5") 
# ax[0].scatter(cv10["Algorithm"],cv10["CorrectPercent"],color="blue",alpha=1,label="cv10")
# ax[0].grid(True)
# ax[0].set_ylim(80,100)
# ax[0].set_xlabel("algorithm")
# ax[0].set_ylabel("correctly-classified percentage (%)")
# ax[0].set_title("Correctly-Classified Instances for Training Data")
# ax[0].legend()

# #row=1, col=0
# ax[1].scatter(cv5["Algorithm"],cv5["MAE"],color="red",alpha=1,label="cv5") #row=0, col=0
# ax[1].scatter(cv10["Algorithm"],cv10["MAE"],color="blue",alpha=1,label="cv10")
# ax[1].grid(True)
# ax[1].set_ylim(0,0.3)
# ax[1].set_xlabel("algorithm")
# ax[1].set_ylabel("MAE")
# ax[1].set_title("MAE for Training Data")
# ax[1].legend()
# ax[1].tick_params(axis='x', labelrotation=45)

# plt.savefig("plots/project_cv.jpg",dpi=300)

# %%
# fig, ax = plt.subplots(2, 3, sharex=True, sharey=False, figsize=(20, 10), dpi=300)

# #row=0, col=0
# ax[0, 0].scatter(train60_tr["Algorithm"],train60_tr["CorrectPercent"],color="red",alpha=1,label="train60") 
# ax[0, 0].scatter(train80_tr["Algorithm"],train80_tr["CorrectPercent"],color="blue",alpha=1,label="train80")
# ax[0, 0].grid(True)
# ax[0, 0].set_ylim(80,100)
# ax[0, 0].set_xlabel("algorithm")
# ax[0, 0].set_ylabel("correctly-classified percentage (%)")
# ax[0, 0].set_title("Correctly-Classified Instances for Training Data")
# ax[0, 0].legend()

# #row=0, col=1
# ax[0, 1].scatter(train60_te["Algorithm"],train60_te["CorrectPercent"],color="red",alpha=1,label="train60") 
# ax[0, 1].scatter(train80_te["Algorithm"],train80_te["CorrectPercent"],color="blue",alpha=1,label="train80")
# ax[0, 1].grid(True)
# ax[0, 1].set_ylim(80,100)
# ax[0, 1].set_xlabel("algorithm")
# # ax[0, 1].set_ylabel("correctly-classified percentage (%)")
# ax[0, 1].set_title("Correctly-Classified Instances for Testing Data")
# ax[0, 1].legend()

# #row=0, col=2
# ax[0, 2].scatter(cv5["Algorithm"],cv5["CorrectPercent"],color="cyan",alpha=1,label="cv5") 
# ax[0, 2].scatter(cv10["Algorithm"],cv10["CorrectPercent"],color="fuchsia",alpha=1,label="cv10")
# ax[0, 2].grid(True)
# ax[0, 2].set_ylim(80,100)
# ax[0, 2].set_xlabel("algorithm")
# ax[0, 2].set_ylabel("correctly-classified percentage (%)")
# ax[0, 2].set_title("Correctly-Classified Instances for Training Data")
# ax[0, 2].legend()

# #row=1, col=0
# ax[1, 0].scatter(train60_tr["Algorithm"],train60_tr["MAE"],color="red",alpha=1,label="train60") #row=0, col=0
# ax[1, 0].scatter(train80_tr["Algorithm"],train80_tr["MAE"],color="blue",alpha=1,label="train80")
# ax[1, 0].grid(True)
# ax[1, 0].set_ylim(0,0.3)
# ax[1, 0].set_xlabel("algorithm")
# ax[1, 0].set_ylabel("MAE")
# ax[1, 0].set_title("MAE for Training Data")
# ax[1, 0].legend()
# ax[1, 0].tick_params(axis='x', labelrotation=45)
# # plt.xticks(rotation=45)

# #row=1, col=1
# ax[1, 1].scatter(train60_te["Algorithm"],train60_te["MAE"],color="red",alpha=1,label="train60") 
# ax[1, 1].scatter(train80_te["Algorithm"],train80_te["MAE"],color="blue",alpha=1,label="train80")
# ax[1, 1].grid(True)
# ax[1, 1].set_ylim(0,0.3)
# ax[1, 1].set_xlabel("algorithm")
# # ax[1, 1].set_ylabel("MAE")
# ax[1, 1].set_title("MAE for Testing Data")
# ax[1, 1].legend()
# ax[1, 1].tick_params(axis='x', labelrotation=45)

# #row=1, col=2
# ax[1, 2].scatter(cv5["Algorithm"],cv5["MAE"],color="cyan",alpha=1,label="cv5") #row=0, col=0
# ax[1, 2].scatter(cv10["Algorithm"],cv10["MAE"],color="fuchsia",alpha=1,label="cv10")
# ax[1, 2].grid(True)
# ax[1, 2].set_ylim(0,0.3)
# ax[1, 2].set_xlabel("algorithm")
# ax[1, 2].set_ylabel("MAE")
# ax[1, 2].set_title("MAE for Training Data")
# ax[1, 2].legend()
# ax[1, 2].tick_params(axis='x', labelrotation=45)

# plt.savefig("plots/project_training_and_testing_combined.jpg",dpi=300)

# %%
# fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False, figsize=(7, 10), dpi=300)

# #row=0, col=0
# ax[0].scatter(train60_tr["Algorithm"],train60_tr["CorrectPercent"],color="red",alpha=1,label="train60") 
# ax[0].scatter(train80_tr["Algorithm"],train80_tr["CorrectPercent"],color="blue",alpha=1,label="train80")
# ax[0].scatter(cv5["Algorithm"],cv5["CorrectPercent"],color="cyan",alpha=1,label="cv5") 
# ax[0].scatter(cv10["Algorithm"],cv10["CorrectPercent"],color="fuchsia",alpha=1,label="cv10")
# ax[0].grid(True)
# ax[0].set_ylim(80,100)
# ax[0].set_xlabel("algorithm")
# ax[0].set_ylabel("correctly-classified percentage (%)")
# ax[0].set_title("Correctly-Classified Instances for Training Data")
# ax[0].legend()

# #row=1, col=0
# ax[1].scatter(train60_tr["Algorithm"],train60_tr["MAE"],color="red",alpha=1,label="train60") #row=0, col=0
# ax[1].scatter(train80_tr["Algorithm"],train80_tr["MAE"],color="blue",alpha=1,label="train80")
# ax[1].scatter(cv5["Algorithm"],cv5["MAE"],color="cyan",alpha=1,label="cv5") #row=0, col=0
# ax[1].scatter(cv10["Algorithm"],cv10["MAE"],color="fuchsia",alpha=1,label="cv10")
# ax[1].grid(True)
# ax[1].set_ylim(0,0.3)
# ax[1].set_xlabel("algorithm")
# ax[1].set_ylabel("MAE")
# ax[1].set_title("MAE for Training Data")
# ax[1].legend()
# ax[1].tick_params(axis='x', labelrotation=45)

# plt.savefig("plots/project_training_combined.jpg",dpi=300)

# %%
Index= ['CERCEVELIK', 'URGUP_SIVRISI']
Cols = ['CERCEVELIK', 'URGUP_SIVRISI']
df = pd.DataFrame([[1168,200],[132,1000]], index=Index, columns=Cols)

sns.heatmap(df, annot=True)



#  a    b   <-- classified as
#  1168  132 |    a = CERCEVELIK
#   200 1000 |    b = URGUP_SIVRISI

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True, sharey=False, figsize=(8, 10), dpi=300)
x_labels = train60_tr["Algorithm"].tolist()
x_train60_tr = np.arange(len(x_labels))
width = 0.2

# row=0, col=0
ax[0].bar(x_train60_tr+width,train60_tr["CorrectPercent"],width,color="lightcoral",alpha=1,label="train60") 
ax[0].bar(x_train60_tr+width*2,train80_tr["CorrectPercent"],width,color="gold",alpha=1,label="train80")
ax[0].bar(x_train60_tr+width*3,cv5["CorrectPercent"],width,color="lightgreen",alpha=1,label="cv5") 
ax[0].bar(x_train60_tr+width*4,cv10["CorrectPercent"],width,color="lightskyblue",alpha=1,label="cv10")
ax[0].grid(True,alpha=0.5)
ax[0].set_xlabel("algorithm")
ax[0].set_ylabel('correctly-classified percentage (%)')
ax[0].set_title('Correctly-Classified Instances for Training Data')
ax[0].legend()

# row=1, col=0
ax[1].bar(x_train60_tr+width,train60_tr["MAE"],width,color="lightcoral",alpha=1,label="train60") 
ax[1].bar(x_train60_tr+width*2,train80_tr["MAE"],width,color="gold",alpha=1,label="train80")
ax[1].bar(x_train60_tr+width*3,cv5["MAE"],width,color="lightgreen",alpha=1,label="cv5") #row=0, col=0
ax[1].bar(x_train60_tr+width*4,cv10["MAE"],width,color="lightskyblue",alpha=1,label="cv10")
ax[1].grid(True,alpha=0.5)
ax[1].set_xlabel("algorithm")
ax[1].set_ylabel('mean absolute error (MAE)')
ax[1].set_title('Mean Absolute Errors (MAE) for Training Data')
ax[1].set_xticks(x_train60_tr, x_labels, rotation=45)
ax[1].legend()

plt.savefig("plots/combined_training_percent_and_mae.jpg",dpi=300)

# %%
fig, ax = plt.subplots(2, 3, sharex=True, sharey=False, figsize=(20, 10), dpi=300)
x_labels = train60_tr["Algorithm"].tolist()
x_train60_tr = np.arange(len(x_labels))
width = 0.4

#row=0, col=0
ax[0, 0].bar(x_train60_tr+width,train60_tr["CorrectPercent"],width,color="lightcoral",alpha=1,label="train60") 
ax[0, 0].bar(x_train60_tr+width*2,train80_tr["CorrectPercent"],width,color="gold",alpha=1,label="train80")
ax[0, 0].grid(True,alpha=0.5)
ax[0, 0].set_ylim(0,100)
ax[0, 0].set_xlabel("algorithm")
# ax[0, 0].set_ylabel("correctly-classified percentage (%)")
ax[0, 0].set_title("Correctly-Classified Instances for Training Data")
ax[0, 0].legend(loc='lower right')

#row=0, col=1
ax[0, 1].bar(x_train60_tr+width,train60_te["CorrectPercent"],width,color="lightcoral",alpha=1,label="train60") 
ax[0, 1].bar(x_train60_tr+width*2,train80_te["CorrectPercent"],width,color="gold",alpha=1,label="train80")
ax[0, 1].grid(True,alpha=0.5)
ax[0, 1].set_ylim(0,100)
ax[0, 1].set_xlabel("algorithm")
# ax[0, 1].set_ylabel("correctly-classified percentage (%)")
ax[0, 1].set_title("Correctly-Classified Instances for Testing Data")
ax[0, 1].legend(loc='lower right')

#row=0, col=2
ax[0, 2].bar(x_train60_tr+width,cv5["CorrectPercent"],width,color="lightgreen",alpha=1,label="cv5") 
ax[0, 2].bar(x_train60_tr+width*2,cv10["CorrectPercent"],width,color="lightskyblue",alpha=1,label="cv10")
ax[0, 2].grid(True,alpha=0.5)
ax[0, 2].set_ylim(0,100)
ax[0, 2].set_xlabel("algorithm")
# ax[0, 2].set_ylabel("correctly-classified percentage (%)")
ax[0, 2].set_title("Correctly-Classified Instances for Training Data")
ax[0, 2].legend(loc='lower right')

#row=1, col=0
ax[1, 0].bar(x_train60_tr+width,train60_tr["MAE"],width,color="lightcoral",alpha=1,label="train60") #row=0, col=0
ax[1, 0].bar(x_train60_tr+width*2,train80_tr["MAE"],width,color="gold",alpha=1,label="train80")
ax[1, 0].grid(True,alpha=0.5)
ax[1, 0].set_ylim(0,0.3)
ax[1, 0].set_xlabel("algorithm")
ax[1, 0].set_ylabel("MAE")
ax[1, 0].set_title("MAE for Training Data")
ax[1, 0].legend()
ax[1, 0].set_xticks(x_train60_tr, x_labels, rotation=45)
# plt.xticks(rotation=45)

#row=1, col=1
ax[1, 1].bar(x_train60_tr+width,train60_te["MAE"],width,color="lightcoral",alpha=1,label="train60") 
ax[1, 1].bar(x_train60_tr+width*2,train80_te["MAE"],width,color="gold",alpha=1,label="train80")
ax[1, 1].grid(True)
ax[1, 1].set_ylim(0,0.3)
ax[1, 1].set_xlabel("algorithm")
# ax[1, 1].set_ylabel("MAE")
ax[1, 1].set_title("MAE for Testing Data")
ax[1, 1].legend()
ax[1, 1].set_xticks(x_train60_tr, x_labels, rotation=45)

#row=1, col=2
ax[1, 2].bar(x_train60_tr+width,cv5["MAE"],width,color="lightgreen",alpha=1,label="cv5") #row=0, col=0
ax[1, 2].bar(x_train60_tr+width*2,cv10["MAE"],width,color="lightskyblue",alpha=1,label="cv10")
ax[1, 2].grid(True)
ax[1, 2].set_ylim(0,0.3)
ax[1, 2].set_xlabel("algorithm")
# ax[1, 2].set_ylabel("MAE")
ax[1, 2].set_title("MAE for Training Data")
ax[1, 2].legend()
ax[1, 2].set_xticks(x_train60_tr, x_labels, rotation=45)

plt.savefig("plots/project_training_and_testing_combined.jpg",dpi=300)
